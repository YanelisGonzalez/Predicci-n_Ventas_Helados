# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
print(np.__version__)
# Out:
# 2.1.3

# %%
df_21 = pd.read_csv('C:/Users/rfg2m/Documents/DATA_SCIENCE/Entregas/Proyectos/MACHINE LEARNING/Jupyter Notebook/Limpieza/archivo21.csv')
df_21
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2021-02-01               11.3             0.00              73.0
# 1    2021-02-02                9.8             0.00              91.0
# 2    2021-02-03               10.0             0.00              88.0
# 3    2021-02-04               10.7             0.00              85.0
# 4    2021-02-05               11.7             0.13              75.0
# ..          ...                ...              ...               ...
# 360  2021-12-29                8.7             0.00              90.0
# 361  2021-12-30                8.1             0.00              79.0
# 362  2021-12-30                8.1             0.00              85.0
# 363  2021-12-31                8.3             0.00              77.0
# 364  2021-12-31                8.3             0.00              81.0
#
#      Radiación_Solar  Velocidad_Viento
# 0              132.0               3.2
# 1               49.0               2.3
# 2               49.0               1.4
# 3               75.0               1.5
# 4              124.0               1.6
# ..               ...               ...
# 360             81.0               0.7
# 361             99.0               0.6
# 362             99.0               0.6
# 363            101.0               0.7
# 364            101.0               0.7
#
# [365 rows x 6 columns]

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              365 non-null    object
#  1   Temperatura_Media  365 non-null    float64
#  2   Precipitaciones    365 non-null    float64
#  3   Humedad_Relativa   365 non-null    float64
#  4   Radiación_Solar    365 non-null    float64
#  5   Velocidad_Viento   365 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 17.2+ KB

# %%
df_21["Fecha"] = pd.to_datetime(df_21["Fecha"])
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              365 non-null    datetime64[ns]
#  1   Temperatura_Media  365 non-null    float64
#  2   Precipitaciones    365 non-null    float64
#  3   Humedad_Relativa   365 non-null    float64
#  4   Radiación_Solar    365 non-null    float64
#  5   Velocidad_Viento   365 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 17.2 KB

# %%
df_21_dup = df_21.duplicated().any()
df_21_dup
# Out:
# np.True_

# %%
df_21_dup = df_21[df_21.duplicated(keep=False)]
df_21_dup
# Out:
#          Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 347 2021-12-23                8.3              0.1              94.0
# 348 2021-12-23                8.3              0.1              94.0
#
#      Radiación_Solar  Velocidad_Viento
# 347             50.0               1.0
# 348             50.0               1.0

# %%
df_21_dup = df_21.drop_duplicates()
df_21_dup
# Out:
#          Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0   2021-02-01               11.3             0.00              73.0
# 1   2021-02-02                9.8             0.00              91.0
# 2   2021-02-03               10.0             0.00              88.0
# 3   2021-02-04               10.7             0.00              85.0
# 4   2021-02-05               11.7             0.13              75.0
# ..         ...                ...              ...               ...
# 360 2021-12-29                8.7             0.00              90.0
# 361 2021-12-30                8.1             0.00              79.0
# 362 2021-12-30                8.1             0.00              85.0
# 363 2021-12-31                8.3             0.00              77.0
# 364 2021-12-31                8.3             0.00              81.0
#
#      Radiación_Solar  Velocidad_Viento
# 0              132.0               3.2
# 1               49.0               2.3
# 2               49.0               1.4
# 3               75.0               1.5
# 4              124.0               1.6
# ..               ...               ...
# 360             81.0               0.7
# 361             99.0               0.6
# 362             99.0               0.6
# 363            101.0               0.7
# 364            101.0               0.7
#
# [364 rows x 6 columns]

# %%
df_21_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              364 non-null    datetime64[ns]
#  1   Temperatura_Media  364 non-null    float64
#  2   Precipitaciones    364 non-null    float64
#  3   Humedad_Relativa   364 non-null    float64
#  4   Radiación_Solar    364 non-null    float64
#  5   Velocidad_Viento   364 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 19.9 KB

# %%
df_22 = pd.read_csv('C:/Users/rfg2m/Documents/DATA_SCIENCE/Entregas/Proyectos/MACHINE LEARNING/Jupyter Notebook/Limpieza/archivo22.csv')
df_22
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2022-01-01                8.2             0.00              73.0
# 1    2022-01-02                7.5             0.00              77.0
# 2    2022-01-03                7.7             0.00              84.0
# 3    2022-01-04                5.4             0.24              90.0
# 4    2022-01-05                5.9             0.15              76.0
# ..          ...                ...              ...               ...
# 390  2022-12-27                8.1              NaN              84.0
# 391  2022-12-28                7.3              NaN              85.0
# 392  2022-12-29                9.9              NaN              89.0
# 393  2022-12-30               11.1              NaN              76.0
# 394  2022-12-31                8.1              NaN              74.0
#
#      Radiación_Solar  Velocidad_Viento
# 0               97.0               0.5
# 1               89.0               0.6
# 2               91.0               0.8
# 3               30.0               1.7
# 4               80.0               1.8
# ..               ...               ...
# 390             92.0               0.7
# 391             93.0               1.1
# 392             57.0               2.4
# 393             64.0               2.8
# 394             94.0               0.7
#
# [395 rows x 6 columns]

# %%
df_22["Fecha"] = pd.to_datetime(df_22["Fecha"])
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              395 non-null    datetime64[ns]
#  1   Temperatura_Media  395 non-null    float64
#  2   Precipitaciones    362 non-null    float64
#  3   Humedad_Relativa   393 non-null    float64
#  4   Radiación_Solar    395 non-null    float64
#  5   Velocidad_Viento   395 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 18.6 KB

# %%
df_22.duplicated().any()
# Out:
# np.True_

# %%
df_23 = pd.read_csv('C:/Users/rfg2m/Documents/DATA_SCIENCE/Entregas/Proyectos/MACHINE LEARNING/Jupyter Notebook/Limpieza/archivo23.csv')
df_23
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2023-02-01                4.1              0.0              67.0
# 1    2023-02-02                6.0              0.0              64.0
# 2    2023-02-03                5.9              0.0              60.0
# 3    2023-02-04                6.6              0.0              56.0
# 4    2023-02-05                7.1              0.0              47.0
# ..          ...                ...              ...               ...
# 360  2023-12-29                4.4              0.0              88.0
# 361  2023-12-30                5.6              0.0              66.0
# 362  2023-12-30                5.6              0.0              82.0
# 363  2023-12-31                6.7              0.0              68.0
# 364  2023-12-31                6.7              0.0              91.0
#
#      Radiación_Solar  Velocidad_Viento
# 0              138.0               0.9
# 1              136.0               0.7
# 2              141.0               0.7
# 3              144.0               0.7
# 4              148.0               0.8
# ..               ...               ...
# 360             38.0               0.6
# 361             95.0               0.7
# 362             95.0               0.7
# 363             56.0               1.8
# 364             56.0               1.8
#
# [365 rows x 6 columns]

# %%
df_23["Fecha"] = pd.to_datetime(df_23["Fecha"])
df_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              365 non-null    datetime64[ns]
#  1   Temperatura_Media  365 non-null    float64
#  2   Precipitaciones    365 non-null    float64
#  3   Humedad_Relativa   365 non-null    float64
#  4   Radiación_Solar    365 non-null    float64
#  5   Velocidad_Viento   365 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 17.2 KB

# %%
df_23.duplicated().any()
# Out:
# np.False_

# %%
df_24 = pd.read_csv('C:/Users/rfg2m/Documents/DATA_SCIENCE/Entregas/Proyectos/MACHINE LEARNING/Jupyter Notebook/Limpieza/archivo24.csv')
df_24
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2024-01-01                5.5             0.00              86.0
# 1    2024-01-02                4.7             0.00              95.0
# 2    2024-01-03               10.5             0.06              98.0
# 3    2024-01-04                8.8             0.10              99.0
# 4    2024-01-05                6.7             0.04              78.0
# ..          ...                ...              ...               ...
# 361  2024-12-27                6.8             0.00              82.0
# 362  2024-12-28                5.3             0.00              80.0
# 363  2024-12-29                4.4             0.00              79.0
# 364  2024-12-30                4.1             0.00              80.0
# 365  2024-12-31                4.0             0.00              77.0
#
#      Radiación_Solar  Velocidad_Viento
# 0               80.0               0.8
# 1               24.0               0.5
# 2               33.0               1.4
# 3               25.0               0.6
# 4              104.0               1.7
# ..               ...               ...
# 361             69.0               0.1
# 362             98.0               0.2
# 363            100.0               0.2
# 364            100.0               0.2
# 365             98.0               0.2
#
# [366 rows x 6 columns]

# %%
df_24["Fecha"] = pd.to_datetime(df_24["Fecha"])
df_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              366 non-null    datetime64[ns]
#  1   Temperatura_Media  366 non-null    float64
#  2   Precipitaciones    366 non-null    float64
#  3   Humedad_Relativa   366 non-null    float64
#  4   Radiación_Solar    366 non-null    float64
#  5   Velocidad_Viento   366 non-null    float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 17.3 KB

# %%
df_24.duplicated().any()
# Out:
# np.False_

# %%
lista_años = [df_21_dup, df_22, df_23, df_24]

# %%
df_years = pd.concat(lista_años, ignore_index=True)
df_years
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2021-02-01               11.3             0.00              73.0
# 1    2021-02-02                9.8             0.00              91.0
# 2    2021-02-03               10.0             0.00              88.0
# 3    2021-02-04               10.7             0.00              85.0
# 4    2021-02-05               11.7             0.13              75.0
# ...         ...                ...              ...               ...
# 1485 2024-12-27                6.8             0.00              82.0
# 1486 2024-12-28                5.3             0.00              80.0
# 1487 2024-12-29                4.4             0.00              79.0
# 1488 2024-12-30                4.1             0.00              80.0
# 1489 2024-12-31                4.0             0.00              77.0
#
#       Radiación_Solar  Velocidad_Viento
# 0               132.0               3.2
# 1                49.0               2.3
# 2                49.0               1.4
# 3                75.0               1.5
# 4               124.0               1.6
# ...               ...               ...
# 1485             69.0               0.1
# 1486             98.0               0.2
# 1487            100.0               0.2
# 1488            100.0               0.2
# 1489             98.0               0.2
#
# [1490 rows x 6 columns]

# %%
df_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              1490 non-null   datetime64[ns]
#  1   Temperatura_Media  1490 non-null   float64
#  2   Precipitaciones    1457 non-null   float64
#  3   Humedad_Relativa   1488 non-null   float64
#  4   Radiación_Solar    1490 non-null   float64
#  5   Velocidad_Viento   1490 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 70.0 KB

# %%
import os

ruta_absoluta = r'C:/Users/rfg2m/Documents/DATA_SCIENCE/Entregas/Proyectos/MACHINE LEARNING/Jupyter Notebook/Limpieza/archivo_ventas.csv'
ruta_relativa = os.path.relpath(ruta_absoluta, os.getcwd())

print(ruta_relativa)

df_v = pd.read_csv(ruta_relativa)
#C:/Users/rfg2m/Documents/DATA_SCIENCE/Entregas/Proyectos/MACHINE LEARNING/Jupyter Notebook/Limpieza/archivo_ventas.csv' 
df_v
# Out:
# archivo_ventas.csv
#            Fecha  Ventas
# 0     2021-01-13   54.00
# 1     2021-01-14   50.15
# 2     2021-01-15   75.50
# 3     2021-01-16   89.45
# 4     2021-01-17  205.55
# ...          ...     ...
# 1182  2024-12-24  321.40
# 1183  2024-12-27  184.40
# 1184  2024-12-28  170.78
# 1185  2024-12-29  248.40
# 1186  2024-12-31  312.08
#
# [1187 rows x 2 columns]

# %%
df_v["Fecha"] = pd.to_datetime(df_v["Fecha"])
df_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   1187 non-null   datetime64[ns]
#  1   Ventas  1187 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 18.7 KB

# %%
df_v.duplicated().any()
# Out:
# np.False_

# %%
df_v
# Out:
#           Fecha  Ventas
# 0    2021-01-13   54.00
# 1    2021-01-14   50.15
# 2    2021-01-15   75.50
# 3    2021-01-16   89.45
# 4    2021-01-17  205.55
# ...         ...     ...
# 1182 2024-12-24  321.40
# 1183 2024-12-27  184.40
# 1184 2024-12-28  170.78
# 1185 2024-12-29  248.40
# 1186 2024-12-31  312.08
#
# [1187 rows x 2 columns]

# %%
media_ventas = df_v['Ventas'].mean()
media_ventas
# Out:
# np.float64(424.31323504633536)

# %%
df_v.describe()
# Out:
#                                Fecha       Ventas
# count                           1187  1187.000000
# mean   2022-12-21 19:22:11.423757312   424.313235
# min              2021-01-13 00:00:00     8.200000
# 25%              2021-12-14 12:00:00   183.770000
# 50%              2022-11-24 00:00:00   365.250000
# 75%              2023-12-14 12:00:00   577.025000
# max              2024-12-31 00:00:00  1884.600000
# std                              NaN   294.625817

# %%
df = pd.merge(df_years, df_v, on='Fecha', how='inner')
df
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2021-02-01               11.3             0.00              73.0
# 1    2021-02-03               10.0             0.00              88.0
# 2    2021-02-04               10.7             0.00              85.0
# 3    2021-02-05               11.7             0.13              75.0
# 4    2021-02-06                8.7             0.05              91.0
# ...         ...                ...              ...               ...
# 1241 2024-12-24                6.4             0.00              71.0
# 1242 2024-12-27                6.8             0.00              82.0
# 1243 2024-12-28                5.3             0.00              80.0
# 1244 2024-12-29                4.4             0.00              79.0
# 1245 2024-12-31                4.0             0.00              77.0
#
#       Radiación_Solar  Velocidad_Viento  Ventas
# 0               132.0               3.2   76.55
# 1                49.0               1.4   46.88
# 2                75.0               1.5  100.06
# 3               124.0               1.6  377.79
# 4                60.0               1.4  292.16
# ...               ...               ...     ...
# 1241             94.0               0.2  321.40
# 1242             69.0               0.1  184.40
# 1243             98.0               0.2  170.78
# 1244            100.0               0.2  248.40
# 1245             98.0               0.2  312.08
#
# [1246 rows x 7 columns]

# %%
# Guardar dataframe en csv
df.to_csv('archivoHelados.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1246 entries, 0 to 1245
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              1246 non-null   datetime64[ns]
#  1   Temperatura_Media  1246 non-null   float64
#  2   Precipitaciones    1222 non-null   float64
#  3   Humedad_Relativa   1244 non-null   float64
#  4   Radiación_Solar    1246 non-null   float64
#  5   Velocidad_Viento   1246 non-null   float64
#  6   Ventas             1246 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 68.3 KB

# %%
df.describe()
# Out:
#                                Fecha  Temperatura_Media  Precipitaciones  \
# count                           1246        1246.000000      1222.000000
# mean   2022-12-25 22:51:48.828250368          16.167929         0.030473
# min              2021-02-01 00:00:00           0.100000         0.000000
# 25%              2021-12-27 06:00:00           9.700000         0.000000
# 50%              2022-11-16 12:00:00          15.400000         0.000000
# 75%              2023-12-13 18:00:00          22.075000         0.000000
# max              2024-12-31 00:00:00          33.800000         1.930000
# std                              NaN           7.679002         0.116821
#
#        Humedad_Relativa  Radiación_Solar  Velocidad_Viento       Ventas
# count       1244.000000      1246.000000       1246.000000  1246.000000
# mean          58.885586       201.210740          1.432826   417.381926
# min           17.000000         1.000000          0.100000     8.200000
# 25%           42.000000       107.000000          0.900000   178.182500
# 50%           60.000000       196.500000          1.300000   355.015000
# 75%           75.000000       291.000000          1.800000   574.875000
# max          100.000000       547.000000          4.500000  1884.600000
# std           19.437018       100.547723          0.710060   293.567391

# %%
df['Precipitaciones'] = df['Precipitaciones'].fillna(0)
df['Humedad_Relativa'] = df['Humedad_Relativa'].fillna(df['Humedad_Relativa'].mean())
df['Radiación_Solar'] = df['Radiación_Solar'].fillna(df['Radiación_Solar'].mean())

# %%
df
# Out:
#           Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0    2021-02-01               11.3             0.00              73.0
# 1    2021-02-03               10.0             0.00              88.0
# 2    2021-02-04               10.7             0.00              85.0
# 3    2021-02-05               11.7             0.13              75.0
# 4    2021-02-06                8.7             0.05              91.0
# ...         ...                ...              ...               ...
# 1241 2024-12-24                6.4             0.00              71.0
# 1242 2024-12-27                6.8             0.00              82.0
# 1243 2024-12-28                5.3             0.00              80.0
# 1244 2024-12-29                4.4             0.00              79.0
# 1245 2024-12-31                4.0             0.00              77.0
#
#       Radiación_Solar  Velocidad_Viento  Ventas
# 0               132.0               3.2   76.55
# 1                49.0               1.4   46.88
# 2                75.0               1.5  100.06
# 3               124.0               1.6  377.79
# 4                60.0               1.4  292.16
# ...               ...               ...     ...
# 1241             94.0               0.2  321.40
# 1242             69.0               0.1  184.40
# 1243             98.0               0.2  170.78
# 1244            100.0               0.2  248.40
# 1245             98.0               0.2  312.08
#
# [1246 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1246 entries, 0 to 1245
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              1246 non-null   datetime64[ns]
#  1   Temperatura_Media  1246 non-null   float64
#  2   Precipitaciones    1222 non-null   float64
#  3   Humedad_Relativa   1244 non-null   float64
#  4   Radiación_Solar    1246 non-null   float64
#  5   Velocidad_Viento   1246 non-null   float64
#  6   Ventas             1246 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 68.3 KB

# %%
df.describe()
# Out:
#                                Fecha  Temperatura_Media  Precipitaciones  \
# count                           1246        1246.000000      1222.000000
# mean   2022-12-25 22:51:48.828250368          16.167929         0.030473
# min              2021-02-01 00:00:00           0.100000         0.000000
# 25%              2021-12-27 06:00:00           9.700000         0.000000
# 50%              2022-11-16 12:00:00          15.400000         0.000000
# 75%              2023-12-13 18:00:00          22.075000         0.000000
# max              2024-12-31 00:00:00          33.800000         1.930000
# std                              NaN           7.679002         0.116821
#
#        Humedad_Relativa  Radiación_Solar  Velocidad_Viento       Ventas
# count       1244.000000      1246.000000       1246.000000  1246.000000
# mean          58.885586       201.210740          1.432826   417.381926
# min           17.000000         1.000000          0.100000     8.200000
# 25%           42.000000       107.000000          0.900000   178.182500
# 50%           60.000000       196.500000          1.300000   355.015000
# 75%           75.000000       291.000000          1.800000   574.875000
# max          100.000000       547.000000          4.500000  1884.600000
# std           19.437018       100.547723          0.710060   293.567391

# %%
print(df['Fecha'].unique())
# Out:
# <DatetimeArray>
# ['2021-02-01 00:00:00', '2021-02-03 00:00:00', '2021-02-04 00:00:00',
#  '2021-02-05 00:00:00', '2021-02-06 00:00:00', '2021-02-07 00:00:00',
#  '2021-02-08 00:00:00', '2021-02-10 00:00:00', '2021-02-11 00:00:00',
#  '2021-02-12 00:00:00',
#  ...
#  '2024-12-18 00:00:00', '2024-12-19 00:00:00', '2024-12-20 00:00:00',
#  '2024-12-21 00:00:00', '2024-12-22 00:00:00', '2024-12-24 00:00:00',
#  '2024-12-27 00:00:00', '2024-12-28 00:00:00', '2024-12-29 00:00:00',
#  '2024-12-31 00:00:00']
# Length: 1166, dtype: datetime64[ns]

# %%
df_23 = df_v[df_v['Fecha'].dt.year == 2023]
df_23
# Out:
#          Fecha  Ventas
# 622 2023-01-06  104.55
# 623 2023-01-07  105.10
# 624 2023-01-08  159.11
# 625 2023-02-01   51.45
# 626 2023-02-02  101.45
# ..         ...     ...
# 898 2023-12-24  216.89
# 899 2023-12-25  226.89
# 900 2023-12-26  104.95
# 901 2023-12-27   91.64
# 902 2023-12-28  154.51
#
# [281 rows x 2 columns]

# %%
print(len(df_23))
# Out:
# 281

# %%
df_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 281 entries, 622 to 902
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   281 non-null    datetime64[ns]
#  1   Ventas  281 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.6 KB

# %%
# Extraer año y mes
df['Año'] = df['Fecha'].dt.year
df['Mes'] = df['Fecha'].dt.month

# %%
print(df['Fecha'].dt.year.unique())
# Out:
# [2021 2022 2023 2024]

# %%
#verificar si hay fechas NaN
print(df['Fecha'].isna().sum())
# Out:
# 0

# %%
print(df.shape)  # Revisa cuántas filas y columnas tienes
print(df['Fecha'].min(), df['Fecha'].max())  # Verifica el rango de fechas
# Out:
# (1246, 9)
# 2021-02-01 00:00:00 2024-12-31 00:00:00

# %%
# Agrupar por mes y año y calcular la media de ventas
ventas_mensuales = df.groupby(['Año', 'Mes'])['Ventas'].mean().reset_index()
ventas_mensuales
# Out:
#      Año  Mes      Ventas
# 0   2021    2  322.180417
# 1   2021    3  457.345385
# 2   2021    4  496.162400
# 3   2021    5  672.284615
# 4   2021    6  569.323214
# 5   2021    7  570.980645
# 6   2021    8  466.995652
# 7   2021    9  414.970000
# 8   2021   10  329.660667
# 9   2021   11  160.735833
# 10  2021   12  139.153585
# 11  2022    1  156.225625
# 12  2022    2  270.602400
# 13  2022    3  212.108148
# 14  2022    4  409.525714
# 15  2022    5  742.946538
# 16  2022    6  757.194828
# 17  2022    7  574.483448
# 18  2022    8  427.016429
# 19  2022    9  508.397037
# 20  2022   10  344.575172
# 21  2022   11  190.634583
# 22  2022   12  142.816364
# 23  2023    2  200.445385
# 24  2023    3  401.872917
# 25  2023    4  635.973846
# 26  2023    5  580.926000
# 27  2023    6  769.496154
# 28  2023    7  695.323077
# 29  2023    8  449.162500
# 30  2023    9  507.310000
# 31  2023   10  349.370400
# 32  2023   11  192.608000
# 33  2023   12  148.690385
# 34  2024    1   96.563750
# 35  2024    2  223.518077
# 36  2024    3  291.392083
# 37  2024    4  613.690000
# 38  2024    5  714.280769
# 39  2024    6  761.738462
# 40  2024    7  585.115385
# 41  2024    8  493.610417
# 42  2024    9  540.353846
# 43  2024   10  286.919167
# 44  2024   11  201.576538
# 45  2024   12  195.042500

# %%
df['Año'] = df['Fecha'].dt.year
print(df['Año'].unique())
# Out:
# [2021 2022 2023 2024]

# %%
# Configurar el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=ventas_mensuales, x='Mes', y='Ventas', hue='Año', marker='o', palette='tab10')
# Etiquetas y título
plt.xlabel('Mes')
plt.ylabel('Ventas Promedio')
plt.title('Ventas mensuales de Helados por Año')
plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.legend(title='Año')
plt.grid(True)

# %%
# Filtrar los datos para el año 2023
ventas_2023 = ventas_mensuales[ventas_mensuales['Año'] == 2024]

# Configurar el gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(data=ventas_2023, x='Mes', y='Ventas', marker='o')

# Etiquetas y título
plt.xlabel('Mes')
plt.ylabel('Ventas Promedio')
plt.title('Ventas mensuales de Helados - Año 2023')
plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
print(df['Fecha'].dtype)
# Out:
# datetime64[ns]

# %%
#Días de mayores Ventas por año

df['Año'] = df['Fecha'].dt.year

dias_max_ventas = df.loc[df.groupby('Año')['Ventas'].idxmax(), ['Fecha', 'Año', 'Ventas']]

print(dias_max_ventas)
# Out:
#           Fecha   Año   Ventas
# 100  2021-05-30  2021  1373.95
# 444  2022-05-01  2022  1438.25
# 738  2023-05-07  2023  1884.60
# 1032 2024-04-14  2024  1535.30

# %%
import datetime
# Datos
fechas_str = ["2021-05-30", "2022-05-01", "2023-05-07", "2024-04-14"]
ventas = [1373.95, 1438.25, 1884.60, 1535.30]

# Convertir las cadenas de fecha a objetos datetime y formatearlas como "día/mes/año"
fechas = [datetime.datetime.strptime(fecha, '%Y-%m-%d') for fecha in fechas_str]
fechas_label = [fecha.strftime('%d/%m/%Y') for fecha in fechas]

colores_pastel = ['#AEC6CF', '#FFB3BA', '#FF677D']

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
barras = plt.bar(fechas_label, ventas, color=colores_pastel)

# Añadir etiquetas y título
plt.xlabel("Fecha (día/mes/año)")
plt.ylabel("Ventas (€)")
plt.title("Ventas por Fecha")

# Añadir el valor de las ventas encima de cada barra
for barra in barras:
    altura = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2, altura + 20, f'{altura:.2f}', 
             ha='center', va='bottom')

plt.tight_layout()

# %%
#Días de menores ventas por año

df['Año'] = df['Fecha'].dt.year

dias_min_ventas = df.loc[df.groupby('Año')['Ventas'].idxmin(), ['Fecha', 'Año', 'Ventas']]

print(dias_min_ventas)
# Out:
#           Fecha   Año  Ventas
# 308  2021-12-26  2021   24.90
# 336  2022-02-01  2022   39.55
# 924  2023-12-09  2023   31.66
# 1019 2024-03-30  2024    8.20

# %%
import datetime
# Datos
fechas_str = ["2021-12-26", "2022-02-01", "2023-12-09", "2024-03-30"]
ventas = [24.90, 39.55, 31.66, 8.20]


# Convertir las cadenas de fecha a objetos datetime y formatearlas como "día/mes/año"
fechas = [datetime.datetime.strptime(fecha, '%Y-%m-%d') for fecha in fechas_str]
fechas_label = [fecha.strftime('%d/%m/%Y') for fecha in fechas]

colores_pastel = ['#A7C7E7', '#C8D9E8', '#A3BFD9']

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
barras = plt.bar(fechas_label, ventas, color=colores_pastel)

# Añadir etiquetas y título
plt.xlabel("Fecha (día/mes/año)")
plt.ylabel("Ventas (€)")
plt.title("Ventas por Fecha")

# Añadir el valor de las ventas encima de cada barra
for barra in barras:
    altura = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2, altura + 0.5, f'{altura:.2f}', 
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Detectar valores Outliers. Seleccionar solo columnas numéricas.
df_numericas = df.select_dtypes(include=[np.number])

def detectar_outliers_iqr(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    outliers = (df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))
    return outliers

outliers_iqr = detectar_outliers_iqr(df_numericas)

print("Número de outliers por columna (IQR):")
print(outliers_iqr.sum())
# Out:
# Número de outliers por columna (IQR):
# Temperatura_Media      0
# Precipitaciones      233
# Humedad_Relativa       0
# Radiación_Solar        0
# Velocidad_Viento      33
# Ventas                27
# Año                    0
# Mes                    0
# dtype: int64

# %%
corr = df.corr()
corr
# Out:
#                       Fecha  Temperatura_Media  Precipitaciones  \
# Fecha              1.000000           0.035577        -0.051045
# Temperatura_Media  0.035577           1.000000        -0.063992
# Precipitaciones   -0.051045          -0.063992         1.000000
# Humedad_Relativa   0.048118          -0.749077         0.283627
# Radiación_Solar   -0.047272           0.742342        -0.211250
# Velocidad_Viento  -0.301746           0.181170         0.151503
# Ventas            -0.006386           0.538829        -0.131081
# Año                0.969448           0.029735        -0.059061
# Mes                0.213711           0.026394         0.024106
#
#                    Humedad_Relativa  Radiación_Solar  Velocidad_Viento  \
# Fecha                      0.048118        -0.047272         -0.301746
# Temperatura_Media         -0.749077         0.742342          0.181170
# Precipitaciones            0.283627        -0.211250          0.151503
# Humedad_Relativa           1.000000        -0.837650         -0.112343
# Radiación_Solar           -0.837650         1.000000          0.208610
# Velocidad_Viento          -0.112343         0.208610          1.000000
# Ventas                    -0.550426         0.668055          0.049241
# Año                        0.000773         0.029878         -0.265866
# Mes                        0.191632        -0.309069         -0.171636
#
#                      Ventas       Año       Mes
# Fecha             -0.006386  0.969448  0.213711
# Temperatura_Media  0.538829  0.029735  0.026394
# Precipitaciones   -0.131081 -0.059061  0.024106
# Humedad_Relativa  -0.550426  0.000773  0.191632
# Radiación_Solar    0.668055  0.029878 -0.309069
# Velocidad_Viento   0.049241 -0.265866 -0.171636
# Ventas             1.000000  0.049815 -0.221640
# Año                0.049815  1.000000 -0.031504
# Mes               -0.221640 -0.031504  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap="coolwarm")
plt.title("Distribución de Ventas")
# Out:
# Text(0.5, 1.0, 'Distribución de Ventas')

# %% [markdown]
# ####  La variable 'target' tiene mayor correlación positiva con la variable predictora 'Radiación Solar' y 'Temperatura Media'. Tiene mayor correlación negativa con la variable 'Humedad_Relativa'

# %%
#Verificar la cantidad de datos que tengo en el df
print(df.shape)
# Out:
# (1246, 9)

# %%
#Verifico la información de las columnas
print(df.columns)
# Out:
# Index(['Fecha', 'Temperatura_Media', 'Precipitaciones', 'Humedad_Relativa',
#        'Radiación_Solar', 'Velocidad_Viento', 'Ventas', 'Año', 'Mes'],
#       dtype='object')

# %% [markdown]
# _______________________________________________________________________________________________

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Variables Temporales (predictoras)
# 1. Fines de semana o festivos: Variable binaria(1: si es fin de semana o festivo, 0: si no)
# 2. Estación del año: Variable de estacionalidad numérica.
# 3. Interacción entre temperatura y humedad: Variable númerica continua, derivada de la multiplicación de ambas variables.

# %%
#Asegurar que la fecha es de tipo datetime
fecha =pd.to_datetime(2021-12-25)

# %%
#Diccionario de los festivos en España(Madrid) años 2021, 2022, 2023 y 2024
festivos_agno = {
    2021: ['2021-01-01', '2021-05-01', '2021-08-15', '2021-10-12', '2021-11-01', '2021-12-06', '2021-12-08', '2021-12-25'],
    2022: ['2022-01-01', '2022-05-01', '2022-08-15', '2022-10-12', '2022-11-01', '2022-12-06', '2022-12-08', '2022-12-25'],
    2023: ['2023-01-01', '2023-05-01', '2023-08-15', '2023-10-12', '2023-11-01', '2023-12-06', '2023-12-08', '2023-12-25'],
    2024: ['2024-01-01', '2024-05-01', '2024-08-15', '2024-10-12', '2024-11-01', '2024-12-06', '2024-12-08', '2024-12-25']
}

# %%
# Convertir las fechas festivas a datetime
festivos = pd.to_datetime(sum(festivos_agno.values(), []))

# %%
# Crear la columna fin de semana o festivo.

df['Fin_de_semana_o_festivo'] = ((df['Fecha'].dt.weekday >= 5) | (df['Fecha'].isin(festivos))).astype(int)

"""df['fecha'].dt.weekday >= 5 → Verifica si la fecha corresponde a un sábado (5) o domingo (6).
df['fecha'].isin(festivos) → Comprueba si la fecha está en la lista de días festivos.
.astype(int) → Convierte el resultado a 1 o 0."""
# Out:
# "df['fecha'].dt.weekday >= 5 → Verifica si la fecha corresponde a un sábado (5) o domingo (6).\ndf['fecha'].isin(festivos) → Comprueba si la fecha está en la lista de días festivos.\n.astype(int) → Convierte el resultado a 1 o 0."

# %%
print(df[['Fecha', 'Fin_de_semana_o_festivo']])
# Out:
#           Fecha  Fin_de_semana_o_festivo
# 0    2021-02-01                        0
# 1    2021-02-03                        0
# 2    2021-02-04                        0
# 3    2021-02-05                        0
# 4    2021-02-06                        1
# ...         ...                      ...
# 1241 2024-12-24                        0
# 1242 2024-12-27                        0
# 1243 2024-12-28                        1
# 1244 2024-12-29                        1
# 1245 2024-12-31                        0
#
# [1246 rows x 2 columns]

# %%
fecha = '2024-10-12'  # Fecha a verificar
es_festivo = pd.to_datetime(fecha) in festivos
print(f"¿{fecha} es festivo?:", es_festivo)
# Out:
# ¿2024-10-12 es festivo?: True

# %%
fecha = '2021-12-25'  # Fecha a verificar
es_festivo = pd.to_datetime(fecha) in festivos
print(f"¿{fecha} es festivo?:", es_festivo)
# Out:
# ¿2021-12-25 es festivo?: True

# %%
fecha = '2024-11-01'  # Fecha a verificar
es_festivo = pd.to_datetime(fecha) in festivos
print(f"¿{fecha} es festivo?:", es_festivo)
# Out:
# ¿2024-11-01 es festivo?: True

# %%
#Crear la variable Estación
# Asignar el número de mes
df['Mes'] = df['Fecha'].dt.month

# Crear la columna 'Estación' (1 = primavera/verano, 0 = otoño/invierno)
df['Estación_Año'] = df['Mes'].apply(lambda x: 1 if x in [3, 4, 5, 6, 7, 8] else 0)

#Los meses [3, 4, 5, 6, 7, 8] corresponden a primavera y verano en el hemisferio norte.

print(df[['Fecha', 'Estación_Año']])
# Out:
#           Fecha  Estación_Año
# 0    2021-02-01             0
# 1    2021-02-03             0
# 2    2021-02-04             0
# 3    2021-02-05             0
# 4    2021-02-06             0
# ...         ...           ...
# 1241 2024-12-24             0
# 1242 2024-12-27             0
# 1243 2024-12-28             0
# 1244 2024-12-29             0
# 1245 2024-12-31             0
#
# [1246 rows x 2 columns]

# %%
#Crear variable de interacción entre humedad y temperatura
# Crear la variable de interacción entre temperatura y humedad
df['Interacción_temp_humedad'] = df['Temperatura_Media'] * df['Humedad_Relativa']

print(df[['Temperatura_Media', 'Humedad_Relativa', 'Interacción_temp_humedad']])
# Out:
#       Temperatura_Media  Humedad_Relativa  Interacción_temp_humedad
# 0                  11.3              73.0                     824.9
# 1                  10.0              88.0                     880.0
# 2                  10.7              85.0                     909.5
# 3                  11.7              75.0                     877.5
# 4                   8.7              91.0                     791.7
# ...                 ...               ...                       ...
# 1241                6.4              71.0                     454.4
# 1242                6.8              82.0                     557.6
# 1243                5.3              80.0                     424.0
# 1244                4.4              79.0                     347.6
# 1245                4.0              77.0                     308.0
#
# [1246 rows x 3 columns]

# %%
df.head()
# Out:
#        Fecha  Temperatura_Media  Precipitaciones  Humedad_Relativa  \
# 0 2021-02-01               11.3             0.00              73.0
# 1 2021-02-03               10.0             0.00              88.0
# 2 2021-02-04               10.7             0.00              85.0
# 3 2021-02-05               11.7             0.13              75.0
# 4 2021-02-06                8.7             0.05              91.0
#
#    Radiación_Solar  Velocidad_Viento  Ventas   Año  Mes  \
# 0            132.0               3.2   76.55  2021    2
# 1             49.0               1.4   46.88  2021    2
# 2             75.0               1.5  100.06  2021    2
# 3            124.0               1.6  377.79  2021    2
# 4             60.0               1.4  292.16  2021    2
#
#    Fin_de_semana_o_festivo  Estación_Año  Interacción_temp_humedad
# 0                        0             0                     824.9
# 1                        0             0                     880.0
# 2                        0             0                     909.5
# 3                        0             0                     877.5
# 4                        1             0                     791.7

# %%
# Guardar dataframe en csv
df.to_csv('archivoHeladosFinal.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1246 entries, 0 to 1245
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Fecha                     1246 non-null   datetime64[ns]
#  1   Temperatura_Media         1246 non-null   float64
#  2   Precipitaciones           1222 non-null   float64
#  3   Humedad_Relativa          1244 non-null   float64
#  4   Radiación_Solar           1246 non-null   float64
#  5   Velocidad_Viento          1246 non-null   float64
#  6   Ventas                    1246 non-null   float64
#  7   Año                       1246 non-null   int32
#  8   Mes                       1246 non-null   int32
#  9   Fin_de_semana_o_festivo   1246 non-null   int64
#  10  Estación_Año              1246 non-null   int64
#  11  Interacción_temp_humedad  1244 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int32(2), int64(2)
# memory usage: 107.2 KB

# %%
df.describe()
# Out:
#                                Fecha  Temperatura_Media  Precipitaciones  \
# count                           1246        1246.000000      1222.000000
# mean   2022-12-25 22:51:48.828250368          16.167929         0.030473
# min              2021-02-01 00:00:00           0.100000         0.000000
# 25%              2021-12-27 06:00:00           9.700000         0.000000
# 50%              2022-11-16 12:00:00          15.400000         0.000000
# 75%              2023-12-13 18:00:00          22.075000         0.000000
# max              2024-12-31 00:00:00          33.800000         1.930000
# std                              NaN           7.679002         0.116821
#
#        Humedad_Relativa  Radiación_Solar  Velocidad_Viento       Ventas  \
# count       1244.000000      1246.000000       1246.000000  1246.000000
# mean          58.885586       201.210740          1.432826   417.381926
# min           17.000000         1.000000          0.100000     8.200000
# 25%           42.000000       107.000000          0.900000   178.182500
# 50%           60.000000       196.500000          1.300000   355.015000
# 75%           75.000000       291.000000          1.800000   574.875000
# max          100.000000       547.000000          4.500000  1884.600000
# std           19.437018       100.547723          0.710060   293.567391
#
#                Año          Mes  Fin_de_semana_o_festivo  Estación_Año  \
# count  1246.000000  1246.000000              1246.000000   1246.000000
# mean   2022.443018     7.023274                 0.333066      0.525682
# min    2021.000000     1.000000                 0.000000      0.000000
# 25%    2021.000000     4.000000                 0.000000      0.000000
# 50%    2022.000000     7.000000                 0.000000      1.000000
# 75%    2023.000000    10.000000                 1.000000      1.000000
# max    2024.000000    12.000000                 1.000000      1.000000
# std       1.103283     3.301007                 0.471499      0.499540
#
#        Interacción_temp_humedad
# count               1244.000000
# mean                 840.704308
# min                    9.600000
# 25%                  652.725000
# 50%                  842.400000
# 75%                 1033.525000
# max                 1672.500000
# std                  288.127305

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap="coolwarm")
plt.title("Distribución de Ventas")
# Out:
# Text(0.5, 1.0, 'Distribución de Ventas')

# %%
# Extraer el mes de la fecha
df["Mes"] = df["Fecha"].dt.month

# Graficar la distribución de las ventas por mes
plt.figure(figsize=(12, 6))
sns.boxplot(x="Mes", y="Ventas", data=df, hue="Mes", palette="coolwarm", legend=False)

# Personalizar el gráfico
plt.xlabel("Mes")
plt.ylabel("Ventas")
plt.title("Distribución de Ventas por Mes")
plt.xticks(ticks=range(12), labels=["Ene", "Feb", "Mar", "Abr", "May", "Jun", "Jul", "Ago", "Sep", "Oct", "Nov", "Dic"])
plt.grid(axis="y", linestyle="--", alpha=0.7)

# %% [markdown]
# ### 1. Tendencia Estacional
#
# Ventas más altas en primavera y verano (Abril - Septiembre), con los meses de Mayo, Junio, Julio y Agosto mostrando medianas elevadas y mayor dispersión.
# Ventas más bajas en invierno (Diciembre - Febrero), con menores valores máximos y menos variabilidad.
#
# ### 2. Distribución de Ventas por Mes
#
# La línea dentro de cada caja representa la mediana (valor central de las ventas).
# La altura de la caja representa el rango intercuartílico (IQR), es decir, la dispersión del 50% de los datos.
# Bigotes (líneas verticales) muestran el rango de valores sin considerar los atípicos.
# Puntos fuera de los bigotes son outliers (valores atípicos), que pueden indicar días con ventas inusualmente altas o bajas.
#
# ### 3. Meses Clave
#
# Abril, Mayo y Junio tienen una mayor dispersión y valores máximos elevados, indicando picos de ventas posiblemente relacionados con el inicio del calor.
# Julio y Agosto mantienen buenas ventas pero con menor variabilidad.
# Octubre - Diciembre muestran valores más bajos y estables, con poca dispersión.
#
# ### 4. Outliers
#
# Hay valores atípicos en casi todos los meses. Esto indica que hubo algunos días con ventas excepcionalmente altas, posiblemente en fines de semana,festivos o cambios bruscos en el clima.
# Estos valores atípicos son relevantes, porque represntan altas ventas con lo cual se aplicará una transformación logarítmica o de raíz cuadrada para reducir la influencia de estos valores sin tener que eliminarlos. Estas transformaciones hacen que los valores grandes tengan un impacto más pequeño y ayudan a estabilizar la varianza.
#
# ### Conclusión
#
# 1. La heladería parece vender más en meses cálidos, lo cual es lógico para un negocio de helados.
# 2. Hay una clara temporada alta entre abril y septiembre y una temporada baja entre octubre y febrero.
# 3. Se pueden explorar estrategias de promoción para los meses con menores ventas.

# %% [markdown]
# ##### La variables features (Temperatura_Media, Estación_Año, Humedad_Relativa, Fin_de_semana_o_festivo, Radiación_Solar) son las que mayor correlación tienen con la variable Target(Ventas).
